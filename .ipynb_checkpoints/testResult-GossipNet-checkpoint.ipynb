# %%
import json
import cv2
import matplotlib.pyplot as plt 
from scipy.special import softmax
import numpy as np

# %% [markdown]
# # take 5 images from train and 5 from test

# %%
trainImages = ["20099217_861b5a76e5_b", "25691390_f9944f61b5_b", "86530608_2c931bb40b_b", "6212161594_1e1c2d022a_b", "6187182607_8d1eba6cf6_b"]
testImages = ["19014116_fbde61c01e_b", "7987560060_c4e5b82ae2_o", "7764246408_05d3df45b1_b", "5663152990_60111361e0_b", "5217423633_9c2269df63_b"]

# %% [markdown]
# plot gt - green color

# %%
def plotGT(i, file, gtboxes, img_scale, mode):
    img = cv2.imread("../FactorizableNet/data/images/vrd/sg_" + mode + "_images/" + file + ".jpg")
    img = cv2.resize(img, None, None, fx=img_scale, fy=img_scale, interpolation=cv2.INTER_LINEAR)

    # save original file
    cv2.imwrite("./gossipnet-visual/" + mode + "/ex" + i + "/" + "original" + ".jpg", img)
    
    # draw gt
    for box in gtboxes:
        x1 = int(box[0])
        y1 = int(box[1])
        x2 = int(box[2])
        y2 = int(box[3])
        
        img = cv2.rectangle(img, (x1, y1), (x2, y2), (0, 250, 0), 2)
        
    cv2.imwrite("./gossipnet-visual/" + mode + "/ex" + i + "/" + "gt" + ".jpg", img)

#     cv2.imshow("img", img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
for i, file in enumerate(trainImages):
    jsonRaw = json.load(open("./output/train_vrd/" + file + ".json"))
    
    gtboxes = jsonRaw['gt_boxes']
    img_scale = jsonRaw['scale']
    
    plotGT(str(i+1), file, gtboxes, img_scale, 'train')

# %%
for i, file in enumerate(testImages):
    jsonRaw = json.load(open("./output/test_vrd/" + file + ".json"))
    
    gtboxes = jsonRaw['gt_boxes']
    img_scale = jsonRaw['scale']
    
    plotGT(str(i+1), file, gtboxes, img_scale, 'test')

# %% [markdown]
# plot all rescored detections

# %%
def plotRDET(i, file, dets, img_scale, mode):
    img = cv2.imread("../FactorizableNet/data/images/vrd/sg_" + mode + "_images/" + file + ".jpg")
    img = cv2.resize(img, None, None, fx=img_scale, fy=img_scale, interpolation=cv2.INTER_LINEAR)

    # draw detections
    for box in dets:
        x1 = int(box[0])
        y1 = int(box[1])
        x2 = int(box[2])
        y2 = int(box[3])
        
        img = cv2.rectangle(img, (x1, y1), (x2, y2), (250, 0, 0), 2)
        
    cv2.imwrite("./gossipnet-visual/" + mode + "/ex" + i + "/" + "dets" + ".jpg", img)

#     cv2.imshow("img", img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
for i, file in enumerate(trainImages):
    jsonRaw = json.load(open("./output/train_vrd/" + file + ".json"))
    
    dets = np.array(jsonRaw['detections'][:350])
    
    new_scores = softmax(np.array(jsonRaw['predictions'])) 
    
    scores_dec_order_index = np.argsort(-new_scores)
    
    dets = dets[scores_dec_order_index[:10]]
    dets = dets.tolist()
    
    print ("image: {}".format(file))
    print ("no gt: {}".format(len(jsonRaw['gt_boxes'])))
    print ("no dets: {}".format(len(dets)))
    
    img_scale = jsonRaw['scale']
    
    plotRDET(str(i+1), file, dets, img_scale, 'train')
# Out:
# image: 20099217_861b5a76e5_b
# no gt: 7
# no dets: 10
# image: 25691390_f9944f61b5_b
# no gt: 10
# no dets: 10
# image: 86530608_2c931bb40b_b
# no gt: 12
# no dets: 10
# image: 6212161594_1e1c2d022a_b
# no gt: 5
# no dets: 10
# image: 6187182607_8d1eba6cf6_b
# no gt: 5
# no dets: 10

# %%
# fileTest = ["8667757362_a059961035_b", "10232487363_57bd85aacc_o", "9259475281_9b0b529beb_b", "228222448_96ae4e4e91_b", "1441389240_b6b98de347_b"]

# %%
for i, file in enumerate(testImages):
    jsonRaw = json.load(open("./output/test_vrd/" + file + ".json"))
    
    dets = np.array(jsonRaw['detections'][:350])
    
    new_scores = softmax(np.array(jsonRaw['predictions'])) 
    
    scores_dec_order_index = np.argsort(-new_scores)
    
    dets = dets[scores_dec_order_index[:10]]
    dets = dets.tolist()
    
    print ("image: {}".format(file))
    print ("no gt: {}".format(len(jsonRaw['gt_boxes'])))
    print ("no dets: {}".format(len(dets)))
    
    img_scale = jsonRaw['scale']
    
    plotRDET(str(i+1), file, dets, img_scale, 'test')
# Out:
# image: 19014116_fbde61c01e_b
# no gt: 11
# no dets: 10
# image: 7987560060_c4e5b82ae2_o
# no gt: 9
# no dets: 10
# image: 7764246408_05d3df45b1_b
# no gt: 11
# no dets: 10
# image: 5663152990_60111361e0_b
# no gt: 16
# no dets: 10
# image: 5217423633_9c2269df63_b
# no gt: 6
# no dets: 10

# %% [markdown]
# drawing quadrant boxes

# %%
def visualizeQuads(file, dets, selected_dets, target_scale, mode):
    img = cv2.imread("../FactorizableNet/data/images/vrd/sg_" + mode + "_images/" + file + ".jpg")

    img_scale = target_scale
    img = cv2.resize(img, None, None, fx=img_scale, fy=img_scale, interpolation=cv2.INTER_LINEAR)

    height = img.shape[0]
    width = img.shape[1]
    
    starth = height/6
    startw = width/6
    
    quadw = width/3
    quadh = height/3
    
    for i in range(3):
        for j in range(3):
            new_img = img.copy()
            
            x = int(startw + i*quadw)
            y = int(starth + j*quadh)
            
            # quadrant limits
            xllim = x - quadw/2
            xulim = x + quadw/2
                
            yllim = y - quadh/2
            yulim = y + quadh/2
            
            # draw the quadrant box
            new_img = cv2.rectangle(new_img, (int(xllim), int(yllim)), (int(xulim), int(yulim)), (255, 255, 255), 5)

            for det in dets:
                x_center = int((det[0] + det[2])/2)
                y_center = int((det[1] + det[3])/2)
                
                if (x_center < xllim or y_center < yllim):
                    continue
                elif (x_center > xulim or y_center > yulim):
                    continue
                
                new_img = cv2.rectangle(new_img, (int(det[0]), int(det[1])), (int(det[2]), int(det[3])), (255, 0, 0), 1)
                
                
            # add a border to the image
            new_img = cv2.copyMakeBorder(new_img, 10, 10, 10, 10, cv2.BORDER_CONSTANT)
    
            cv2.imshow("img", new_img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

#             if (folderSave):
#                 cv2.imwrite(folderSave + str(i) + "_" + str(j) + ".jpg", new_img)

# %%
for i, file in enumerate(trainImages):
    jsonRaw = json.load(open("./output/train_vrd/" + file + ".json"))
    
    dets = np.array(jsonRaw['detections'][:350])
    
    new_scores = softmax(np.array(jsonRaw['predictions'])) 
    scores_dec_order_index = np.argsort(-new_scores)
    selected_dets = dets[scores_dec_order_index[:10]]
    
    dets = dets.tolist()
    selected_dets = selected_dets.tolist()
    
    print ("image: {}".format(file))
    print ("no gt: {}".format(len(jsonRaw['gt_boxes'])))
    print ("no dets: {}".format(len(dets)))
    
    img_scale = jsonRaw['scale']
    
    visualizeQuads(file, dets, selected_dets, img_scale, 'train')
    
    break
# Out:
# image: 20099217_861b5a76e5_b
# no gt: 7
# no dets: 350
# image: 25691390_f9944f61b5_b
# no gt: 10
# no dets: 238
# image: 86530608_2c931bb40b_b
# no gt: 12
# no dets: 350
# image: 6212161594_1e1c2d022a_b
# no gt: 5
# no dets: 350
# image: 6187182607_8d1eba6cf6_b
# no gt: 5
# no dets: 350

# %%
jsonData2 = json.load(open("./output/test_vrd/19014116_fbde61c01e_b.json"))

# %%
jsonData2['predictions']
# Out:
# [-4.902016639709473,
#  -7.765392303466797,
#  -3.1354317665100098,
#  2.0749096870422363,
#  1.425690770149231,
#  -1.1432538032531738,
#  -4.5749616622924805,
#  -1.9811928272247314,
#  -4.258293628692627,
#  -6.681586265563965,
#  -5.330333232879639,
#  -2.017953872680664,
#  -3.4481143951416016,
#  -4.786294460296631,
#  -4.748588562011719,
#  -8.996932983398438,
#  -7.599876880645752,
#  -8.74390697479248,
#  -5.408968925476074,
#  -5.414615631103516,
#  -7.413942337036133,
#  -3.8917131423950195,
#  -2.618201732635498,
#  -3.7212393283843994,
#  -4.852563858032227,
#  -2.803781509399414,
#  -0.7510022521018982,
#  -1.7259950637817383,
#  -3.731297254562378,
#  -8.136857032775879,
#  -3.791186809539795,
#  -4.196614742279053,
#  -8.566689491271973,
#  -6.476532936096191,
#  -3.8246090412139893,
#  -4.9692277908325195,
#  -1.922871470451355,
#  -3.82731556892395,
#  -6.311882972717285,
#  -10.551011085510254,
#  -4.593234062194824,
#  -3.5340538024902344,
#  -7.310153484344482,
#  -8.066356658935547,
#  -5.109362602233887,
#  -6.490126132965088,
#  -4.168302059173584,
#  -4.730474948883057,
#  -10.34846305847168,
#  -9.893171310424805,
#  -7.562235355377197,
#  -4.564614772796631,
#  -9.155498504638672,
#  -8.3599214553833,
#  -2.0995211601257324,
#  -11.799408912658691,
#  -7.749975204467773,
#  -6.15320348739624,
#  -6.71392297744751,
#  -8.259693145751953,
#  -10.983011245727539,
#  -8.652168273925781,
#  -2.025024652481079,
#  -6.352790832519531,
#  -9.320989608764648,
#  -1.1180773973464966,
#  -7.257221221923828,
#  -8.257859230041504,
#  -7.962050437927246,
#  -7.616223335266113,
#  -2.7398598194122314,
#  -3.685372829437256,
#  -8.57399845123291,
#  -4.228104591369629,
#  -6.308416843414307,
#  -3.932814836502075,
#  -7.441713333129883,
#  -2.774648904800415,
#  -7.945183277130127,
#  -5.848912239074707,
#  -2.7805933952331543,
#  -6.048060417175293,
#  -4.7347211837768555,
#  -4.504661560058594,
#  -6.613722801208496,
#  -5.971845626831055,
#  -4.9709978103637695,
#  -9.14773178100586,
#  -8.634771347045898,
#  -11.383554458618164,
#  -8.507915496826172,
#  -13.43887710571289,
#  -6.035343647003174,
#  -6.838478088378906,
#  -4.06700325012207,
#  -5.1437530517578125,
#  -5.817907333374023,
#  -7.114307880401611,
))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-e209ad09713b> in <module>
# ----> 1 jsonData = json.load(open("./test_result.json"))
#
# FileNotFoundError: [Errno 2] No such file or directory: './test_result.json'

# %%
jsonData.keys()
# Out:
# dict_keys(['scale', 'file_name', 'predictions', 'detections', 'gt_boxes', 'scores'])

# %%
len(jsonData['detections'][:350])
# Out:
# 350

# %%
jsonData['file_name']
# Out:
# '19014116_fbde61c01e_b.json'

# %%
len(jsonData['predictions'])
# Out:
# 350

# %%
new_scores = jsonData['predictions']

# %%
new_scores
# Out:
# [-7.061354637145996,
#  -4.878665924072266,
#  0.3664308786392212,
#  4.964405059814453,
#  5.510326385498047,
#  -5.345272064208984,
#  -4.805596828460693,
#  -1.8507254123687744,
#  -8.101358413696289,
#  -9.88670539855957,
#  -0.1242837905883789,
#  -3.8505771160125732,
#  -3.760653257369995,
#  -6.790578365325928,
#  -9.703450202941895,
#  -9.955609321594238,
#  -9.974157333374023,
#  -2.580718517303467,
#  -4.580283164978027,
#  -5.230842590332031,
#  -3.510071277618408,
#  -6.150820732116699,
#  -3.591597318649292,
#  -4.156023025512695,
#  -5.08546257019043,
#  2.372007369995117,
#  -0.9371599555015564,
#  -3.6039090156555176,
#  -4.296243667602539,
#  -19.38461685180664,
#  -3.924285411834717,
#  -5.068236827850342,
#  -18.757587432861328,
#  -12.740091323852539,
#  -3.669829845428467,
#  -7.25353479385376,
#  -2.006492853164673,
#  -3.9510934352874756,
#  -8.249129295349121,
#  -8.190740585327148,
#  0.36755186319351196,
#  -9.495716094970703,
#  -4.467931270599365,
#  -10.064337730407715,
#  -12.278823852539062,
#  -14.5042724609375,
#  -3.1249630451202393,
#  -2.3370699882507324,
#  -12.315705299377441,
#  -7.947240829467773,
#  -17.867481231689453,
#  -5.643531322479248,
#  -11.319833755493164,
#  -10.340794563293457,
#  0.0928797572851181,
#  -19.73016357421875,
#  -2.929466962814331,
#  -9.15224838256836,
#  -16.582778930664062,
#  -13.371804237365723,
#  -17.738218307495117,
#  -12.572750091552734,
#  0.5302037000656128,
#  -4.653052806854248,
#  -19.815170288085938,
#  1.6442049741744995,
#  -6.940339088439941,
#  -6.667960166931152,
#  -8.007725715637207,
#  -8.240861892700195,
#  2.1653764247894287,
#  -5.923920631408691,
#  -10.908341407775879,
#  -2.9489054679870605,
#  -11.665332794189453,
#  -10.124116897583008,
#  -11.281704902648926,
#  -5.720694065093994,
#  -3.6034927368164062,
#  -8.353975296020508,
#  -9.939075469970703,
#  -3.335444688796997,
#  -5.113861083984375,
#  -10.177339553833008,
#  -7.962736129760742,
#  -7.087139129638672,
#  -7.208437442779541,
#  -15.248446464538574,
#  -16.786828994750977,
#  -14.854037284851074,
#  -16.58671760559082,
#  -24.21163558959961,
#  -8.050858497619629,
#  -13.20267391204834,
#  -7.538061141967773,
#  -10.721231460571289,
#  -14.018844604492188,
#  -20.95431137084961,
#  -6.647528648376465,
#  -20.186891555786133,
#  -13.001656532287598,
#  -11.223928451538086,
#  -11.008099555969238,
#  -15.75561237335205,
#  -5.298539638519287,
#  -16.368858337402344,
#  -19.412818908691406,
#  -8.689170837402344,
#  -13.769427299499512,
#  -5.809218406677246,
#  -7.408011436462402,
#  -6.7985711097717285,
#  -8.722332000732422,
#  -16.136829376220703,
#  -4.238949775695801,
#  -7.962646484375,
#  -16.67566680908203,
#  -19.72808837890625,
#  -3.596174716949463,
#  -10.174259185791016,
#  -16.40065574645996,
#  -14.543333053588867,
#  -20.148038864135742,
#  -7.344683647155762,
#  -31.763402938842773,
#  -21.690444946289062,
#  -24.44770050048828,
#  -25.656692504882812,
#  -24.955886840820312,
#  -26.624588012695312,
#  -21.425525665283203,
#  -25.757165908813477,
#  -20.330570220947266,
#  -25.20029067993164,
#  -10.3185453414917,
#  -25.744169235229492,
#  -26.92576789855957,
#  -26.918642044067383,
#  -18.678985595703125,
#  -11.862414360046387,
#  -28.328094482421875,
#  -12.800638198852539,
#  -22.24774169921875,
#  -14.262907981872559,
#  -21.209373474121094,
#  -26.153079986572266,
#  -25.664409637451172,
#  -21.477937698364258,
#  -11.816779136657715,
#  -25.727230072021484,
#  -22.304019927978516,
#  -25.42835235595703,
#  -29.253023147583008,
#  -27.093664169311523,
#  -26.311012268066406,
#  -17.828989028930664,
#  -20.648326873779297,
#  -21.221830368041992,
#  -21.603137969970703,
#  -16.9753360748291,
#  -14.988140106201172,
#  -28.056867599487305,
#  -18.073139190673828,
#  -25.863555908203125,
#  -28.780826568603516,
#  -25.51882553100586,
#  -23.247032165527344,
#  -25.031780242919922,
#  -22.851232528686523,
#  -31.97032928466797,
#  -15.656794548034668,
#  -20.5059871673584,
#  -17.57033920288086,
#  -16.369422912597656,
#  -22.858352661132812,
#  -3.790062665939331,
#  -28.534244537353516,
#  -9.632742881774902,
#  -31.30817413330078,
#  -22.387359619140625,
#  -22.699609756469727,
#  -25.011417388916016,
#  -23.448829650878906,
#  -22.64296531677246,
#  -29.383169174194336,
#  -7.090368747711182,
#  -29.148513793945312,
#  -20.9764347076416,
#  -11.300012588500977,
#  -27.953218460083008,
#  -28.97649574279785,
#  -19.273815155029297,
#  -21.315187454223633,
#  -23.51530647277832,
#  -24.75116539001465,
#  -21.112504959106445,
#  -15.637511253356934,
#  -26.295982360839844,
#  -20.963520050048828,
#  -33.286582946777344,
#  -21.94000816345215,
#  -28.971982955932617,
#  -24.409595489501953,
#  -18.075220108032227,
#  -26.57452964782715,
#  -23.197355270385742,
#  -20.13910484313965,
#  -24.264955520629883,
#  -29.17406463623047,
#  -24.525495529174805,
#  -25.778879165649414,
#  -22.51352310180664,
#  -22.46746063232422,
#  -6.8283586502075195,
#  -28.219161987304688,
#  -33.01952362060547]

# %%
dets = jsonData['detections'][:350]

# %%
cond = np.array(new_scores) > 0

# %%
new_scores
# Out:
# array([False, False, False, False,  True, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
cond
# Out:
# array([False, False,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False,  True, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
np.sum(cond)
# Out:
# 9

# %%
np.asarray(dets)[cond].tolist()
# Out:
# [[0.0, 279.86020739504016, 280.76710062595953, 599.0],
#  [39.58984691031861, 164.6715276062406, 350.80891719875484, 599.0],
#  [462.6392008382474, 23.12666600207504, 788.3849665572841, 489.9060115231829],
#  [119.28390070503045, 219.59417019785087, 389.46338794517544, 599.0],
#  [208.34425728979988, 29.66324186546791, 788.3518380607267, 535.8717576778324],
#  [544.2731666300228, 88.93507874422178, 767.4831031768306, 383.87542274350017],
#  [103.07814842617222, 4.170095086033172, 839.0, 289.27074625030184],
#  [369.106033497275, 292.587317198326, 439.73191811900176, 365.2797622116484],
#  [0.0, 16.685489452597693, 699.1853851805301, 301.4127905981177]]

# %%
dets[cond.tolist()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-c0e5614926d3> in <module>
# ----> 1 dets[cond.tolist()]
#
# TypeError: list indices must be integers or slices, not list

# %%
file_name = jsonData['file_name']
file_name
# Out:
# '19014116_fbde61c01e_b.json'

# %%
len(jsonData['detections'])
# Out:
# 1002

# %%
dets = jsonData['detections'][:350]

# %%
gt = jsonData['gt_boxes']

# %%
len(gt)
# Out:
# 11

# %%
new_scores = jsonData['predictions']

# %%
index = []
count = 0
for i, val in enumerate(new_scores):
    if val > 0:
        index.append(i)
        count += 1
print (count)
# Out:
# 9

# %%
# drawing boxes and getting an idea

# %%
json = json.load(open("./data/vrd/test/" + file_name))

# %%
len(json['gt_boxes'])
# Out:
# 11

# %%
file_name
# Out:
# '19014116_fbde61c01e_b.json'

# %%
img = cv2.imread("../FactorizableNet/data/images/vrd/sg_test_images/" + file_name.split(".")[0] + ".jpg")
img_scale = json['scale']
img = cv2.resize(img, None, None, fx=img_scale, fy=img_scale, interpolation=cv2.INTER_LINEAR)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2BGRA)
img = cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255, 0.1), 2)

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# plotting detection's - 350
new_img = img.copy()
for i, box in enumerate(dets):
    x1 = int(box[0])
    y1 = int(box[1])
    x2 = int(box[2])
    y2 = int(box[3])
    upperLeft = (250, 250)
    lowerRight = (700, 700)
    
    new_img = cv2.rectangle(new_img, upperLeft, lowerRight, (255, 0, 0), 2)
    
    if (x1 > upperLeft[0] and y1 > upperLeft[1]):
        if (x2 < lowerRight[0] and y2 < lowerRight[1]):
            new_img = cv2.rectangle(new_img, (x1, y1), (x2, y2), (0, 0, 255, 0.9), 2)
            
            if i in index:
                new_img = cv2.rectangle(new_img, (x1, y1), (x2, y2), (0, 0, 255), 2)

new_img = cv2.copyMakeBorder(new_img, 10, 10, 10, 10, cv2.BORDER_CONSTANT)

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
    
ax.imshow(cv2.cvtColor(new_img, cv2.COLOR_BGR2RGB), aspect='equal')

# cv2.imshow('img', new_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# plotting gt
new_img = img.copy()
for box in gt:
    new_img = cv2.rectangle(new_img, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (0, 255, 0), 2)

new_img = cv2.copyMakeBorder(new_img, 10, 10, 10, 10, cv2.BORDER_CONSTANT)

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
    
ax.imshow(cv2.cvtColor(new_img, cv2.COLOR_BGR2RGB), aspect='equal')
    
# cv2.imshow('img', new_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
new_img = img.copy()
for i, box in enumerate(dets):
    if i in index:
        new_img = cv2.rectangle(new_img, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (0, 0, 255), 2)

new_img = cv2.copyMakeBorder(new_img, 10, 10, 10, 10, cv2.BORDER_CONSTANT)
  
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
    
ax.imshow(cv2.cvtColor(new_img, cv2.COLOR_BGR2RGB), aspect='equal')    
    
# cv2.imshow('img', new_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
